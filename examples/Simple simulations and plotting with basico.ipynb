# %% [markdown]
# ## Test 2

# %%
import sys
sys.path.append('..')
# %matplotlib inline

# %%
from basico import *

# %% [markdown]
# ### Load a model

# %%
biomod = load_biomodel(10)

# %% [markdown]
# ### Run time course

# %% [markdown]
# #### Time course duration 100

# %%
tc = run_time_course(duration = 100)
tc.plot()

# %% [markdown]
# #### Time course duration 3000

# %%
tc = run_time_course(duration = 3000)
tc.plot()

# %% [markdown]
# ### Get compartments

# %%
get_compartments()
# Out:
#      expression initial_expression  initial_size            key  rate  size  \
# name
# uVol                                         1.0  Compartment_0   0.0   1.0
#
#        type unit
# name
# uVol  fixed    l

# %% [markdown]
# ### Get parameters ("global quantities")

# %%
get_parameters() # no global quantities

# %% [markdown]
# ### Show experimental data from the model

# %%
get_experiment_data_from_model()
# Out:
# []

# %% [markdown]
# ### Run steady state

# %%
run_steadystate()
get_species()
# Out:
#         compartment  concentration expression  initial_concentration  \
# name
# Mek1-P         uVol      41.142140                              10.0
# Erk2-P         uVol      99.971352                              10.0
# Mos            uVol      76.635083                              90.0
# Mek1           uVol     238.913726                             280.0
# Erk2           uVol     102.158541                             280.0
# Mek1-PP        uVol      19.944135                              10.0
# Mos-P          uVol      23.364917                              10.0
# Erk2-PP        uVol      97.870107                              10.0
#
#         initial_expression  initial_particle_number           key  \
# name
# Mek1-P                                 6.022141e+15  Metabolite_3
# Erk2-P                                 6.022141e+15  Metabolite_6
# Mos                                    5.419927e+16  Metabolite_0
# Mek1                                   1.686199e+17  Metabolite_2
# Erk2                                   1.686199e+17  Metabolite_5
# Mek1-PP                                6.022141e+15  Metabolite_4
# Mos-P                                  6.022141e+15  Metabolite_1
# Erk2-PP                                6.022141e+15  Metabolite_7
#
#          particle_number     rate       type    unit
# name
# Mek1-P      2.477638e+16  0.18750  reactions  nmol/l
# Erk2-P      6.020416e+16  0.00000  reactions  nmol/l
# Mos         4.615073e+16  0.00000  reactions  nmol/l
# Mek1        1.438772e+17  0.00000  reactions  nmol/l
# Erk2        6.152131e+16 -0.40625  reactions  nmol/l
# Mek1-PP     1.201064e+16 -0.18750  reactions  nmol/l
# Mos-P       1.407068e+16  0.00000  reactions  nmol/l
# Erk2-PP     5.893876e+16  0.40625  reactions  nmol/l

# %% [markdown]
# ## Use pandas syntax for indexing and plotting

# %%
tc = run_time_course(model = biomod, duration = 4000)
tc.plot()

# %%
tc.loc[:, ['Mek1', 'Mek1-P', 'Mos']].plot()

# %% [markdown]
# ## Get parameter sets

# %%
model = biomod.getModel()
sets = model.getModelParameterSets()
sets.size()
# Out:
# 0
