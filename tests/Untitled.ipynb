# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('simulation_log.tsv', sep='\t')

# %%
df[['measurement']] = np.log(df[['measurement']])

# %%
df
# Out:
#          observableId simulationConditionId  time  measurement
# 0    observable_x_0ac             condition   inf    -0.290686
# 1    observable_x_0ac             condition   inf    -0.289240
# 2    observable_x_0ac             condition   inf    -0.292469
# 3    observable_x_0ac             condition   inf    -0.293003
# 4    observable_x_0ac             condition   inf    -0.308323
# ..                ...                   ...   ...          ...
# 247  observable_x_k16             condition   inf    -3.500572
# 248  observable_x_k16             condition   inf    -3.450204
# 249  observable_x_k16             condition   inf    -3.485566
# 250  observable_x_k16             condition   inf    -3.407775
# 251  observable_x_k16             condition   inf    -3.376356
#
# [252 rows x 4 columns]

# %%
# !cat simulation_log.tsv
# Out:
# observableId	simulationConditionId	time	measurement
# observable_x_0ac	condition	inf	-0.2906855723117731
# observable_x_0ac	condition	inf	-0.2892399534518036
# observable_x_0ac	condition	inf	-0.2924686850923775
# observable_x_0ac	condition	inf	-0.29300322188975686
# observable_x_0ac	condition	inf	-0.30832331727336115
# observable_x_0ac	condition	inf	-0.29119711645359675
# observable_x_0ac	condition	inf	-0.3403377659222368
# observable_x_0ac	condition	inf	-0.35080928517152565
# observable_x_0ac	condition	inf	-0.37522636814463395
# observable_x_0ac	condition	inf	-0.3505352858430187
# observable_x_0ac	condition	inf	-0.37437595177640176
# observable_x_0ac	condition	inf	-0.32546263016690974
# observable_x_0ac	condition	inf	-0.30842190276954606
# observable_x_0ac	condition	inf	-0.3123703529548693
# observable_x_0ac	condition	inf	-0.30543127058942804
# observable_x_0ac	condition	inf	-0.3074746168227935
# observable_x_0ac	condition	inf	-0.24075140407354162
# ...

# %%
df.to_csv('simulation_log.tsv', index=None, sep='\t')
